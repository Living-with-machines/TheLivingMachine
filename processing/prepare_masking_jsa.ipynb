# %%
import pandas as pd
import re

# %%
before_df = pd.read_csv("jsa_sentences/jsa_metadataJSA_before1854.tsv", sep="\t")
after_df = pd.read_csv("jsa_sentences/jsa_metadataJSA_1854-1908.tsv", sep="\t")
both_df = pd.concat([before_df, after_df])

# %%
def process_content(query_tokens, article_id):
    with open("jsa_sentences/JSA_content/" + str(article_id) + ".txt") as fr:
        lines = fr.readlines()
        lines = [line.replace("\n", "").strip() for line in lines]
        lSentenceTuples = []
        for iline in range(len(lines)):
            prevSentence = ""
            nextSentence = ""
            if iline > 0:
                prevSentence = lines[iline - 1]
            if iline < len(lines) - 1:
                nextSentence = lines[iline + 1]
            currentSentence = lines[iline]
            
            matches = re.findall(r"(?=("+'|'.join(query_tokens)+r"))", currentSentence, re.IGNORECASE)
            matches = list(set(matches))
            
            for match in matches:
                targetExpression = match
                markedSentence = re.sub(r"\b%s\b" % match, "$***" + match + "***$", currentSentence, 1, flags=re.IGNORECASE)
                maskedSentence = re.sub(r"\b%s\b" % match, " [MASK] ", currentSentence, 1, flags=re.IGNORECASE)
                maskedSentence = re.sub(" +", " ", maskedSentence)
                    
                lSentenceTuples.append((prevSentence, currentSentence, markedSentence, maskedSentence, nextSentence, targetExpression))
                
    return lSentenceTuples

# %%
query_tokens = ["machine", "machines", "machinery", "engines", "engine", "locomotive", "locomotives", "turbine", "turbines", "apparatus", "apparatuses", "motor" "motors", "compressor", "compressors", "accumulator", "accumulators", "dynamo", "dynamos"]
query_tokens_re = [r"\b" + x + r"\b" for x in query_tokens]

df_cols = list(both_df.columns) + ["prevSentence", "currentSentence", "markedSentence", "maskedSentence", "nextSentence", "targetExpression"]
df_rows = []

for i, row in both_df.iterrows():
    tSentences = process_content(query_tokens_re, row["article_id"])
    for t in tSentences:
        prevSentence, currentSentence, markedSentence, maskedSentence, nextSentence, targetExpression = t
        df_rows.append(list(row) + [prevSentence, currentSentence, markedSentence, maskedSentence, nextSentence, targetExpression])

# %%
df_sentences = pd.DataFrame(df_rows, columns=df_cols)

# %%
# Keep only sentences shorter than 512 characters
df_sentences = df_sentences[df_sentences["maskedSentence"].str.len() < 510]

# %%
df_sentences.to_pickle("../data/jsa_animacy.pkl")

# %%
pd.read_pickle("../data/jsa_animacy.pkl").head()
# Out:
#                            filename journal_id journal_id_text  \
# 0  journal-article-10.2307_41326898  j50003411      transoclon
# 1  journal-article-10.2307_41326898  j50003411      transoclon
# 3  journal-article-10.2307_41325349  j50003411      transoclon
# 4  journal-article-10.2307_41325349  j50003411      transoclon
# 5  journal-article-10.2307_41325349  j50003411      transoclon
#
#                                        journal_title publisher_name  volume  \
# 0  Transactions of the Society, Instituted at Lon...    The Society      54
# 1  Transactions of the Society, Instituted at Lon...    The Society      54
# 3  Transactions of the Society, Instituted at Lon...    The Society      19
# 4  Transactions of the Society, Instituted at Lon...    The Society      19
# 5  Transactions of the Society, Instituted at Lon...    The Society      19
#
#    issue   issue_id  article_id      article_type  ...  \
# 0    NaN  i40060851    41326898  research-article  ...
# 1    NaN  i40060851    41326898  research-article  ...
# 3    NaN  i40060557    41325349              misc  ...
# 4    NaN  i40060557    41325349              misc  ...
# 5    NaN  i40060557    41325349              misc  ...
#
#                      title_group        date  \
# 0  NO. IV. TEMPORARY DIVING-BELL  1844-01-01
# 1  NO. IV. TEMPORARY DIVING-BELL  1844-01-01
# 3                        PREFACE  1801-01-01
# 4                        PREFACE  1801-01-01
# 5                        PREFACE  1801-01-01
#
#                                         contributors       subjects  \
# 0  [{'given-names': 'Thomas', 'surname': 'Dickins...  ['MECHANICS']
# 1  [{'given-names': 'Thomas', 'surname': 'Dickins...  ['MECHANICS']
# 3                                                 []             []
# 4                                                 []             []
# 5                                                 []             []
#
#                                         prevSentence  \
# 0                                               LIY.
# 1  These were used throughout the whole of the op...
# 3  Mr. Palmer's method of Housing Corn in Wet Wea...
# 4  The Drill Husbandry continues to gain advocate...
# 5  The advantages of the Drill over the Broad-cas...
#
#                                      currentSentence  \
# 0  H 98 MECHANICS. being able to procure a diving...
# 1  A more powerful air-pump was also constructed ...
# 3  The more general introduction of Thrashing-Mac...
# 4  The Public are under great obligations to Thom...
# 5  The fnethod which he suggests for the preserva...
#
#                                       markedSentence  \
# 0  H 98 MECHANICS. being able to procure a diving...
# 1  A more powerful air-pump was also constructed ...
# 3  The more general introduction of Thrashing-$**...
# 4  The Public are under great obligations to Thom...
# 5  The fnethod which he suggests for the preserva...
#
#                                       maskedSentence  \
# 0  H 98 MECHANICS. being able to procure a diving...
# 1  A more powerful air-pump was also constructed ...
# 3  The more general introduction of Thrashing- [M...
# 4  The Public are under great obligations to Thom...
# 5  The fnethod which he suggests for the preserva...
#
#                                         nextSentence targetExpression
# 0  He next had an air-pump constructed under his ...          machine
# 1  The first diving-bell used in the operations w...        apparatus
# 3  Immense tracts of Land lie unculti- vated in d...         Machines
# 4  This very ingeni- ous mid useful implement pos...          Machine
# 5  Mr. EcclestOn, - of Scarisbrkk, who has for ma...          Machine
#
# [5 rows x 23 columns]

# %%
pd.read_pickle("../data/jsa_animacy.pkl").iloc[0].currentSentence
# Out:
# "H 98 MECHANICS. being able to procure a diving-bell at Rio de Janeiro, nor the means of casting one, it occurred to him that it was possible to make such a machine of iron water-tanks, strengthened with bars of iron, &amp;c ; and he obtained the Admiral's order to be furnished with two two-ton tanks from the Warspite (flag-ship)."

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_lg")

# %%
doc = nlp("being able to procure a diving-bell at Rio de Janeiro, nor the means of casting one, it occurred to him that it was possible to make such a machine of iron water-tanks, strengthened with bars of iron, &amp;c ; and he obtained the Admiral's order to be furnished with two two-ton tanks from the Warspite (flag-ship).")

# %%
dfplay = pd.read_pickle("../data/jsa_animacy.pkl")
dfplay = dfplay[dfplay["targetExpression"] == "engine"]

for i, row in dfplay.iloc[40:50].iterrows():
    doc = nlp(row["currentSentence"])
    print(row["currentSentence"])
    for token in doc:
        print(token.text, token.pos_, token.dep_, token.head.text)
    print()
    print()
# Out:
# 118 TowER-engine, account of a machine so called, in Cornwall, by Mr. Smea- ton, v. 190 - , its cost and complexity, v. 190 Towns, great.
# 118 NUM nummod engine
# TowER PROPN compound engine
# - PUNCT punct engine
# engine NOUN ROOT engine
# , PUNCT punct engine
# account NOUN appos engine
# of ADP prep account
# a DET det machine
# machine NOUN pobj of
# so ADV advmod called
# called VERB acl machine
# , PUNCT punct called
# in ADP prep called
# Cornwall PROPN pobj in
# , PUNCT punct account
# by ADP prep engine
# Mr. PROPN pobj by
# Smea- ADJ amod ton
# ton NOUN npadvmod engine
# , PUNCT punct engine
# v. CCONJ prep engine
# 190 NUM conj engine
# - PUNCT punct engine
# , PUNCT punct engine
# its PRON poss cost
# cost NOUN conj engine
# and CCONJ cc cost
# complexity NOUN conj cost
# , PUNCT punct cost
# v. CCONJ cc cost
# 190 NUM nummod Towns
# Towns NOUN pobj v.
# , PUNCT punct cost
# great ADJ amod cost
# . PUNCT punct engine
#
#
# 370 Water, Paris supplied with it by an English steam-engine, iv. introd.
# 370 NUM nummod Water
# Water NOUN ROOT Water
# , PUNCT punct supplied
# Paris PROPN nsubj supplied
# supplied VERB acl Water
# with ADP prep supplied
# it PRON pobj with
# by ADP agent supplied
# an DET det engine
# English ADJ amod engine
# steam NOUN compound engine
# - PUNCT punct engine
# engine NOUN pobj by
# , PUNCT punct engine
# iv X appos Water
# . PUNCT punct Water
# introd X ROOT introd
# . PUNCT punct introd
#
#
# The mode of working a railway by this plan, with any amount of traffic, may be thus described : - Suppose the distance between the terminal and the nearest principal intermediate station, and between the two principal intermediate stations to be twenty miles re- spectively, this distance is made up of two engine-runs of equal length meeting together at the half-way stations.
# The DET det mode
# mode NOUN nsubjpass described
# of ADP prep mode
# working VERB pcomp of
# a DET det railway
# railway NOUN dobj working
# by ADP prep working
# this DET det plan
# plan NOUN pobj by
# , PUNCT punct mode
# with ADP prep mode
# any DET det amount
# amount NOUN pobj with
# of ADP prep amount
# traffic NOUN pobj of
# , PUNCT punct described
# may AUX aux described
# be AUX auxpass described
# thus ADV advmod described
# described VERB ROOT described
# : PUNCT punct described
# - PUNCT punct described
# Suppose VERB xcomp described
# the DET det distance
# distance NOUN dobj Suppose
# between ADP prep distance
# the DET det terminal
# terminal NOUN pobj between
# and CCONJ cc terminal
# the DET det station
# nearest ADJ amod station
# principal ADJ amod station
# intermediate ADJ amod station
# station NOUN conj terminal
# , PUNCT punct Suppose
# and CCONJ cc Suppose
# between ADP prep made
# the DET det stations
# two NUM nummod stations
# principal ADJ amod stations
# intermediate ADJ amod stations
# stations NOUN pobj between
# to PART aux be
# be VERB xcomp between
# twenty NUM nummod miles
# miles NOUN npadvmod re-
# re- ADV advmod spectively
# spectively ADV advmod be
# , PUNCT punct made
# this DET det distance
# distance NOUN nsubjpass made
# is AUX auxpass made
# made VERB conj Suppose
# up ADP prt made
# of ADP prep made
# two NUM nummod runs
# engine NOUN compound runs
# - PUNCT punct runs
# runs NOUN pobj of
# of ADP prep runs
# equal ADJ amod length
# length NOUN compound meeting
# meeting NOUN pobj of
# together ADV advmod meeting
# at ADP prep meeting
# the DET det stations
# half ADJ amod way
# - PUNCT punct way
# way NOUN compound stations
# stations NOUN pobj at
# . PUNCT punct described
#
#
# An engine (No. 1) starts from the terminal station a, and another (No. 2) from the first principal intermediate station d, as the clock strikes 8, at an average speed of 25 miles an hour, including stop- pages, the engines Nos. 1 and 2 will arrive by 24 minutes after 8 at the exchange station c, where each engine-run is furnished with a large turn-table, capable of holding the engine and tender together ; an engine (No. 3) is already on the up-line ready to proceed with ILLUSTRATIONS.
# An DET det engine
# engine NOUN nsubj starts
# ( PUNCT punct engine
# No NOUN intj engine
# . NOUN appos engine
# 1 NUM nummod .
# ) PUNCT punct engine
# starts VERB ROOT starts
# from ADP prep starts
# the DET det station
# terminal ADJ amod station
# station NOUN pobj from
# a DET dobj starts
# , PUNCT punct a
# and CCONJ cc a
# another DET conj a
# ( PUNCT punct No
# No NOUN parataxis another
# . NOUN npadvmod starts
# 2 NUM nummod .
# ) PUNCT punct .
# from ADP prep starts
# the DET det d
# first ADJ amod d
# principal ADJ amod station
# intermediate ADJ amod station
# station NOUN compound d
# d NOUN pobj from
# , PUNCT punct starts
# as ADP prep starts
# the DET det strikes
# clock NOUN compound strikes
# strikes NOUN pobj as
# 8 NUM nummod strikes
# , PUNCT punct strikes
# at ADP prep starts
# an DET det speed
# average ADJ amod speed
# speed NOUN pobj at
# of ADP prep speed
# 25 NUM nummod miles
# miles NOUN pobj of
# an DET det hour
# hour NOUN npadvmod miles
# , PUNCT punct speed
# including VERB prep speed
# stop- ADJ amod pages
# pages NOUN pobj including
# , PUNCT punct starts
# the DET det engines
# engines NOUN appos engine
# Nos PROPN appos engines
# . PROPN punct starts
# 1 NUM nsubj arrive
# and CCONJ cc 1
# 2 NUM conj 1
# will AUX aux arrive
# arrive VERB ROOT arrive
# by ADP prep arrive
# 24 NUM nummod minutes
# minutes NOUN pobj by
# after ADP prep minutes
# 8 NUM pobj after
# at ADP prep arrive
# the DET det station
# exchange NOUN compound station
# station NOUN pobj at
# c NOUN dep arrive
# , PUNCT punct c
# where ADV advmod furnished
# each DET det run
# engine NOUN compound run
# - PUNCT punct run
# run NOUN nsubjpass furnished
# is AUX auxpass furnished
# furnished VERB relcl c
# with ADP prep furnished
# a DET det table
# large ADJ amod table
# turn NOUN compound table
# - PUNCT punct table
# table NOUN pobj with
# , PUNCT punct furnished
# capable ADJ amod c
# of ADP prep capable
# holding VERB pcomp of
# the DET det engine
# engine NOUN dobj holding
# and CCONJ cc holding
# tender VERB conj holding
# together ADV advmod tender
# ; PUNCT punct c
# an DET det engine
# engine NOUN nsubj is
# ( PUNCT punct engine
# No NOUN intj engine
# . NOUN appos engine
# 3 NUM nummod .
# ) PUNCT punct engine
# is VERB conj arrive
# already ADV advmod is
# on ADP prep is
# the DET det line
# up ADJ amod line
# - PUNCT punct line
# line NOUN pobj on
# ready ADJ amod line
# to PART aux proceed
# proceed VERB xcomp ready
# with ADP prep proceed
# ILLUSTRATIONS NOUN pobj with
# . PUNCT punct is
#
#
# The engines Nos. 1 and 2, which have just arrived, are turned into the engine-sheds on either side, and the engines Nos. 3 and 4 are connected with the up and down-trains respectively, and proceed forward precisely at 8h.
# The DET det engines
# engines NOUN nsubjpass turned
# Nos PROPN appos engines
# . PROPN punct engines
# 1 NUM appos engines
# and CCONJ cc 1
# 2 NUM conj 1
# , PUNCT punct engines
# which DET nsubj arrived
# have AUX aux arrived
# just ADV advmod arrived
# arrived VERB relcl engines
# , PUNCT punct turned
# are AUX auxpass turned
# turned VERB ROOT turned
# into ADP prep turned
# the DET det sheds
# engine NOUN compound sheds
# - PUNCT punct sheds
# sheds VERB pobj into
# on ADP prep sheds
# either DET det side
# side NOUN pobj on
# , PUNCT punct turned
# and CCONJ cc turned
# the DET det engines
# engines NOUN nsubjpass connected
# Nos PROPN appos engines
# . PROPN appos engines
# 3 NUM appos engines
# and CCONJ cc engines
# 4 NUM conj engines
# are AUX auxpass connected
# connected VERB conj turned
# with ADP prep connected
# the DET det trains
# up ADJ amod trains
# and CCONJ cc up
# down NOUN conj up
# - PUNCT punct trains
# trains NOUN pobj with
# respectively ADV advmod connected
# , PUNCT punct connected
# and CCONJ cc connected
# proceed VERB conj connected
# forward ADV advmod proceed
# precisely ADV advmod at
# at ADP prep proceed
# 8h NUM pobj at
# . PUNCT punct connected
#
#
# 54m. engine No. 3 with the up-train will reach the arrival platform of the terminal station a, where the passengers and luggage will be despatched by omnibuses, &amp;c.
# 54 NUM nummod m.
# m. NOUN compound engine
# engine NOUN nsubj reach
# No NOUN appos engine
# . NOUN appos engine
# 3 NUM nummod .
# with ADP prep engine
# the DET det train
# up ADJ compound train
# - PUNCT punct train
# train NOUN pobj with
# will AUX aux reach
# reach VERB ROOT reach
# the DET det platform
# arrival NOUN compound platform
# platform NOUN dobj reach
# of ADP prep platform
# the DET det station
# terminal ADJ amod station
# station NOUN pobj of
# a DET dep reach
# , PUNCT punct a
# where ADV advmod despatched
# the DET det passengers
# passengers NOUN nsubjpass despatched
# and CCONJ cc passengers
# luggage NOUN conj passengers
# will AUX aux despatched
# be AUX auxpass despatched
# despatched VERB relcl a
# by ADP agent despatched
# omnibuses NOUN pobj by
# , PUNCT punct despatched
# & CCONJ cc despatched
# amp;c PROPN conj despatched
# . PUNCT punct reach
#
#
# In the mean time the 9 o'clock down-train is preparing to start with engine No. 5, which has its steam up, and is waiting for the 9 o'clock bell to be rung, or bugle sounded.
# In ADP prep preparing
# the DET det time
# mean ADJ amod time
# time NOUN pobj In
# the DET det train
# 9 NUM nummod o'clock
# o'clock NOUN nmod train
# down ADV compound train
# - PUNCT punct train
# train NOUN nsubj preparing
# is AUX aux preparing
# preparing VERB ROOT preparing
# to PART aux start
# start VERB xcomp preparing
# with ADP prep start
# engine NOUN pobj with
# No NOUN npadvmod start
# . NOUN dobj start
# 5 NUM nummod .
# , PUNCT punct .
# which DET nsubj has
# has VERB relcl .
# its PRON poss steam
# steam NOUN dobj has
# up ADP prt steam
# , PUNCT punct preparing
# and CCONJ cc preparing
# is AUX aux waiting
# waiting VERB conj preparing
# for ADP mark rung
# the DET det bell
# 9 NUM nummod o'clock
# o'clock NOUN compound bell
# bell NOUN nsubjpass rung
# to PART aux rung
# be AUX auxpass rung
# rung VERB advcl waiting
# , PUNCT punct rung
# or CCONJ cc rung
# bugle NOUN nsubj sounded
# sounded VERB conj rung
# . PUNCT punct sounded
#
#
# At 24 minutes past 9, engine No. 5 will arrive with the second down-train at exchange station c, and engine No 6 will also arrive, within a minute before or after, with a second up-train at the same station ; as on the first exchange, so again engines Nos. 1 and 2 are ready to proceed, on the signal being given at 9h.
# At ADP prep arrive
# 24 NUM nummod minutes
# minutes NOUN pobj At
# past ADP prep minutes
# 9 NUM pobj past
# , PUNCT punct arrive
# engine NOUN compound No
# No NOUN nsubj arrive
# . NOUN appos No
# 5 NUM nummod .
# will AUX aux arrive
# arrive VERB ROOT arrive
# with ADP prep arrive
# the DET det train
# second ADJ amod train
# down ADJ amod train
# - PUNCT punct train
# train NOUN pobj with
# at ADP prep train
# exchange NOUN compound station
# station NOUN pobj at
# c NOUN conj train
# , PUNCT punct c
# and CCONJ cc c
# engine NOUN punct arrive
# No DET det 6
# 6 NUM nsubj arrive
# will AUX aux arrive
# also ADV advmod arrive
# arrive VERB ccomp engines
# , PUNCT punct arrive
# within ADP prep arrive
# a DET det minute
# minute NOUN pobj within
# before ADP prep minute
# or CCONJ cc before
# after ADP conj before
# , PUNCT punct arrive
# with ADP prep arrive
# a DET det train
# second ADJ amod train
# up ADJ amod train
# - PUNCT punct train
# train NOUN pobj with
# at ADP prep train
# the DET det station
# same ADJ amod station
# station NOUN pobj at
# ; PUNCT punct engines
# as ADP prep engines
# on ADP prep as
# the DET det exchange
# first ADJ amod exchange
# exchange NOUN pobj on
# , PUNCT punct engines
# so ADV advmod again
# again ADV advmod engines
# engines VERB ROOT engines
# Nos PROPN nsubj engines
# . PROPN punct engines
# 1 NUM nsubj are
# and CCONJ cc 1
# 2 NUM conj 1
# are AUX ROOT are
# ready ADJ acomp are
# to PART aux proceed
# proceed VERB xcomp ready
# , PUNCT punct are
# on ADP prep are
# the DET det signal
# signal NOUN pobj on
# being AUX auxpass given
# given VERB acl signal
# at ADP prep given
# 9h NOUN pobj at
# . PUNCT punct are
#
#
# Engines Nos. 5 and 6 are turned into the engine-sheds as before, and prepared to make the next exchange ; at 9h.
# Engines PROPN compound Nos
# Nos PROPN nsubjpass turned
# . PUNCT punct Nos
# 5 NUM appos Nos
# and CCONJ cc Nos
# 6 NUM conj Nos
# are AUX auxpass turned
# turned VERB ROOT turned
# into ADP prep turned
# the DET det sheds
# engine NOUN compound sheds
# - PUNCT punct sheds
# sheds NOUN pobj into
# as ADP prep turned
# before ADV pcomp as
# , PUNCT punct turned
# and CCONJ cc turned
# prepared VERB conj turned
# to PART aux make
# make VERB xcomp prepared
# the DET det exchange
# next ADJ amod exchange
# exchange NOUN dobj make
# ; PUNCT punct prepared
# at ADP prep prepared
# 9h NOUN pobj at
# . PUNCT punct turned
#
#
# 54m. engine No. 1 arrives at the terminal station a, as before, and engine No. 3 is again ready to start with the 10 o'clock train, and so the reciprocating process is continued throughout the 24 hours at each of the intermediate exchange stations* о 194 ILLUSTRATIONS.
# 54 NUM nummod m.
# m. NOUN compound engine
# engine NOUN nsubj arrives
# No NOUN appos engine
# . NOUN appos engine
# 1 NUM nummod .
# arrives VERB ROOT arrives
# at ADP prep arrives
# the DET det station
# terminal ADJ amod station
# station NOUN pobj at
# a DET nmod arrives
# , PUNCT punct a
# as ADP advmod before
# before ADV advmod a
# , PUNCT punct a
# and CCONJ cc a
# engine NOUN compound No
# No NOUN nsubj is
# . NOUN appos No
# 3 NUM nummod .
# is VERB conj arrives
# again ADV advmod is
# ready ADJ acomp is
# to PART aux start
# start VERB xcomp ready
# with ADP prep start
# the DET det train
# 10 NUM nummod o'clock
# o'clock NOUN compound train
# train NOUN pobj with
# , PUNCT punct is
# and CCONJ cc is
# so ADV advmod continued
# the DET det process
# reciprocating VERB amod process
# process NOUN nsubjpass continued
# is AUX auxpass continued
# continued VERB conj is
# throughout ADP prep continued
# the DET det hours
# 24 NUM nummod hours
# hours NOUN pobj throughout
# at ADP prep hours
# each DET pobj at
# of ADP prep each
# the DET det stations
# intermediate ADJ amod stations
# exchange NOUN compound stations
# stations NOUN pobj of
# * PUNCT punct stations
# о X nmod ILLUSTRATIONS
# 194 NUM nummod ILLUSTRATIONS
# ILLUSTRATIONS NOUN appos stations
# . PUNCT punct continued
